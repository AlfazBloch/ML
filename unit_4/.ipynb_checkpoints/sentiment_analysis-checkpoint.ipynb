# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\atmiya\AppData\Roaming\nltk_data...
# True

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

sentences = [
    "I love this product",
    "This is my worse expirence",
    "It is okay,not good"
]

for text in sentences:
    scores = analyzer.polarity_scores(text)
    print(text,"-->",scores)
# Out:
# I love this product --> {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}
# This is my worse expirence --> {'neg': 0.437, 'neu': 0.563, 'pos': 0.0, 'compound': -0.4767}
# It is okay,not good --> {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}

# %%
import librosa
import librosa.display
from matplotlib import pyplot as plt

audio_file = 'sample.wav'
y,sr = librosa.load(audio_file)

plt.figure(figsize=(10,5))
librosa.display.waveshow(y,sr=sr) 
plt.title("Audio wave")
plt.xlabel('Seconds')
plt.ylabel('Amplitude')
# Out:
# Text(76.09722222222221, 0.5, 'Amplitude')
